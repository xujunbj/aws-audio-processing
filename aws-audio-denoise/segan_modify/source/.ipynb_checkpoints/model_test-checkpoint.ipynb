# %%
# !sh train_segan.sh
# Out:
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p27/lib/python2.7/site-packages/tensorflow_core/__init__.py:1467: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
#
# WARNING:tensorflow:From main.py:124: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# ...

# %%
# !sh clean_wav.sh ../../test/record_noise_28_clip_0.wav ../../result
# Out:
# INPUT NOISY WAV: ../../test/record_noise_28_clip_0.wav
# SAVE PATH: ../../result
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p27/lib/python2.7/site-packages/tensorflow_core/__init__.py:1467: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
#
# WARNING:tensorflow:From main.py:124: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# ...
